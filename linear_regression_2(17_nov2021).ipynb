# %%
import pandas as pd

# %%
df=pd.read_csv("E:\\notebooks file\\WT_AT.csv")

# %%
df
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Waist   109 non-null    float64
#  1   AT      109 non-null    float64
# dtypes: float64(2)
# memory usage: 1.8 KB

# %%
df.corr()
# Out:
#           Waist        AT
# Waist  1.000000  0.818558
# AT     0.818558  1.000000

# %%
import seaborn as sns
sns.distplot(df.Waist)
# Out:
# C:\Users\Server\AppData\Local\Temp\ipykernel_8116\1119857708.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Waist)
# <Axes: xlabel='Waist', ylabel='Density'>

# %%
sns.distplot(df.AT)
# Out:
# C:\Users\Server\AppData\Local\Temp\ipykernel_8116\1099533662.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.AT)
# <Axes: xlabel='AT', ylabel='Density'>

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.Waist,df.AT)

# %%
import statsmodels.formula.api as smf
model=smf.ols("AT~Waist",data=df).fit()

# %%
sns.regplot(x='Waist',y='AT',data=df)
# Out:
# <Axes: xlabel='Waist', ylabel='AT'>

# %%
model.params
# Out:
# Intercept   -215.981488
# Waist          3.458859
# dtype: float64

# %%
print(model.tvalues,'/n',model.pvalues)
# Out:
# Intercept    -9.909103
# Waist        14.740376
# dtype: float64 /n Intercept    8.197416e-17
# Waist        1.618607e-27
# dtype: float64

# %%
model.rsquared,model.rsquared_adj
# Out:
# (0.6700368930528429, 0.6669531256981966)

# %%
newdata=pd.Series([74.75,72.6])

# %%
newdata
# Out:
# 0    74.75
# 1    72.60
# dtype: float64

# %%
df_pred=pd.DataFrame(newdata,columns=['Waist'])

# %%
df_pred
# Out:
#    Waist
# 0  74.75
# 1  72.60

# %%
model.predict(df_pred)
# Out:
# 0    42.568252
# 1    35.131704
# dtype: float64
